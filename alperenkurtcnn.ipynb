# %% [markdown]
# 1. ❗ [Proje Hakkında](#proje-hakkinda)
#    1.1 🎯 [Proje Amacı](#proje-amaci)
#    1.2 📊 [Veri Seti Bilgisi](#veri-seti-bilgisi)
#
# 2. 🚩 [Hazırlık](#hazirlik)
#    2.1 📔 [Kütüphaneleri İçe Aktarma](#kutuphaneleri-ice-aktarma)
#    2.2 🗃️ [Veri Setini Yükleme](#veri-setini-yukleme)
#    2.3 ⚙️ [Geliştirme Ortamı Ayarları](#gelistirme-ortami-ayarlari)
#
# 3. 🧹 [Veri Önişleme](#veri-onisleme)
#    3.1 📸 [Görüntü Formatı Dönüştürme](#goruntu-formati-donusturme)
#    3.2 🏷️ [Etiketleme İşlemleri](#etiketleme-islemleri)
#    3.3 📊 [Veri Görselleştirme ve İstatistikler](#veri-gorsellestirme)
#    3.4 🎲 [Train-Validation-Test Ayırma](#train-validation-test-ayirma)
#    3.5 🔄 [Data Augmentation (Veri Çoğaltma)](#data-augmentation)
#    3.5.1 🔄 [Rotation (Döndürme)](#rotation)
#    3.5.2 ↔️ [Flip (Çevirme)](#flip)
#    3.5.3 🔍 [Zoom (Yakınlaştırma)](#zoom)
#    3.5.4 🎨 [Color Jitter (Renk Değişimi)](#color-jitter)
#
# 4. 🏗️ [Model Tasarımı](#model-tasarimi)
#    4.1 🧠 [CNN Mimarisi Oluşturma](#cnn-mimarisi)
#    4.1.1 🔗 [Convolutional Layers](#convolutional-layers)
#    4.1.2 🏊 [Pooling Layers](#pooling-layers)
#    4.1.3 🎯 [Dropout Katmanları](#dropout-katmanlari)
#    4.1.4 🔗 [Dense Layers (Fully Connected)](#dense-layers)
#    4.1.5 ⚡ [Aktivasyon Fonksiyonları](#aktivasyon-fonksiyonlari)
#    4.2 🎯 [Transfer Learning (Bonus)](#transfer-learning)
#
# 5. 🎚️ [Model Eğitimi](#model-egitimi)
#    5.1 ⚙️ [Model Derleme](#model-derleme)
#    5.2 🏃 [Eğitim Süreci](#egitim-sureci)
#    5.3 📈 [Eğitim İzleme](#egitim-izleme)
#
# 6. 📊 [Model Değerlendirmesi](#model-degerlendirmesi)
#    6.1 📈 [Accuracy ve Loss Grafikleri](#accuracy-loss-grafikleri)
#    6.2 🎯 [Confusion Matrix](#confusion-matrix)
#    6.3 📋 [Classification Report](#classification-report)
#    6.4 🔥 [Heatmap Görselleştirme (Grad-CAM/Eigen-CAM)](#heatmap-gorsellestirme)
#    6.4.1 👁️ [Model Karar Bölgeleri](#model-karar-bolgeleri)
#
# 7. 🎛️ [Hiperparametre Optimizasyonu](#hiperparametre-optimizasyonu)
#    7.1 🔧 [Manuel Optimizasyon](#manuel-optimizasyon)
#    7.1.1 📐 [Katman Sayısı](#katman-sayisi)
#    7.1.2 🔢 [Filtre Sayısı](#filtre-sayisi)
#    7.1.3 📏 [Kernel Boyutları](#kernel-boyutlari)
#    7.1.4 💧 [Dropout Oranı](#dropout-orani)
#    7.1.5 🔗 [Dense Layer Boyutları](#dense-layer-boyutlari)
#    7.1.6 📊 [Learning Rate](#learning-rate)
#    7.1.7 📦 [Batch Size](#batch-size)
#    7.1.8 ⚡ [Optimizer Seçimi](#optimizer-secimi)
#    7.2 🤖 [Otomatik Optimizasyon (Bonus)](#otomatik-optimizasyon)
#    7.2.1 🎯 [Bayesian Optimization](#bayesian-optimization)
#    7.2.2 🎲 [Random Search](#random-search)
#    7.2.3 🔍 [Grid Search](#grid-search)
#    7.2.4 🎛️ [Keras Tuner](#keras-tuner)
#
# 8. 🛡️ [Model Regularizasyonu](#model-regularizasyonu)
#    8.1 ⚖️ [Overfitting Kontrolü](#overfitting-kontrolu)
#    8.2 📈 [Overfitting/Underfitting Analizi](#overfitting-underfitting-analizi)
#    8.3 🔧 [Regularization Teknikleri](#regularization-teknikleri)
#    8.3.1 📉 [L2 Regularization](#l2-regularization)
#    8.3.2 💧 [Dropout](#dropout)
#
# 9. 📊 [Model İzleme (Bonus)](#model-izleme)
#    9.1 📈 [TensorBoard Entegrasyonu](#tensorboard)
#    9.2 ⚖️ [Weights & Biases](#weights-biases)
#
# 10. ✅ [Sonuçlar ve Yorumlar](#sonuclar-ve-yorumlar)
#     10.1 🎯 [Model Başarı Skoru](#model-basari-skoru)
#     10.2 📈 [Performans Analizi](#performans-analizi)
#     10.3 🔍 [Kullanılan Yöntemler](#kullanilan-yontemler)
#     10.4 💡 [Elde Edilen Bulgular](#elde-edilen-bulgular)
#
# 11. 🛞 [Değerlendirme Kriterleri](#degerlendirme-kriterleri)
#     11.1 ✅ [Kaggle Notebook + GitHub Repo + README.md](#proje-teslimi)
#     11.2 🧹 [Veri Önişleme + Data Augmentation](#veri-isleme-kriterleri)
#     11.3 🧠 [CNN Tabanlı Model](#model-kriterleri)
#     11.4 📊 [Model Değerlendirme Detayları](#degerlendirme-detaylari)
#     11.5 🔥 [Grad-CAM/Eigen-CAM Görselleştirme](#gorsellestirme-kriterleri)
#     11.6 🎛️ [Hiperparametre Optimizasyonu](#optimizasyon-kriterleri)
#
# 12. 🎓 [Kişisel Deneyim ve Öğrenilenler](#kisisel-deneyim)
#     12.1 🔐 [Ana Bulgular](#ana-bulgular)
#     12.2 ☝️ [İpuçları ve Öneriler](#ipuclari)
#     12.3 ✍️ [Proje Süreci Değerlendirmesi](#proje-sureci-degerlendirmesi)
#     12.4 🚀 [Gelecek Çalışmalar](#gelecek-calismalar)

# %% [markdown]
# ## 1. ❗ Proje Hakkında
# <a id="proje-hakkinda"></a>

# %% [markdown]
# <a id="proje-amaci"></a>
# ### 1.1 🎯 Proje Amacı

# %% [markdown]
#     Sorun Tanımı
#     Göğüs röntgeni görüntülerinden pnömoni teşhisi koymak, radyolojistler için zaman alıcı ve uzmanlık gerektiren bir süreçtir. Manuel değerlendirme süreçleri hem zaman kaybına hem de insan kaynaklı hatalara yol açabilmektedir. Mevcut binlerce göğüs röntgeni görüntüsünün manuel olarak değerlendirilmesi önemli bir iş yükü oluşturmaktadır.
#
#     Görevim
#     Bu proje kapsamında, göğüs röntgeni görüntülerinden pnömoni varlığını otomatik tespit edebilen bir CNN modeli geliştirmeyi planlıyorum. 5,863 adet röntgen görüntüsü kullanarak NORMAL ve PNEUMONIA sınıfları arasında tahmin yapan bir model oluşturacağım.

# %% [markdown]
# <a id="veri-seti-bilgisi"></a>
# ### 1.2 📊 Veri Seti Bilgisi

# %% [markdown]
#     Temel Özellikler
#     * Veri Seti: Chest X-Ray Images (Pneumonia)
#     * Toplam Görüntü: 5,863 adet JPEG röntgen görüntüsü
#     * Sınıflar: 2 sınıf (NORMAL, PNEUMONIA)
#     * Bölümler: train, test, validation setleri
#
#     Kaynak ve Kalite:
#     * Hastane: Guangzhou Women and Children's Medical Center*
#     * Yaş Grubu: 1-5 yaş pediatrik hastalar
#     * Doğrulama: İki uzman hekim tarafından etiketlenmiş
#     * Lisans: CC BY 4.0
#     * Link: https://www.kaggle.com/datasets/paultimothymooney/chest-xray-pneumonia

# %% [markdown]
# ## 2. 🚩 Hazırlık
# <a id="hazirlik"></a>

# %% [markdown]
# ## 3. 🧹 Veri Önişleme
# <a id="veri-onisleme"></a>

# %% [markdown]
# ## 4. 🏗️ Model Tasarımı
# <a id="model-tasarimi"></a>

# %% [markdown]
# ## 5. 🎚️ Model Eğitimi
# <a id="model-egitimi"></a>

# %% [markdown]
# ## 6. 📊 Model Değerlendirmesi
# <a id="model-degerlendirmesi"></a>

# %% [markdown]
# ## 7. 🎛️ Hiperparametre Optimizasyonu
# <a id="hiperparametre-optimizasyonu"></a>

# %% [markdown]
# ## 8. 🛡️ Model Regularizasyonu
# <a id="model-regularizasyonu"></a>

# %% [markdown]
# ## 9. 📊 Model İzleme (Bonus)
# <a id="model-izleme"></a>

# %% [markdown]
# ## 10. ✅ Sonuçlar ve Yorumlar
# <a id="sonuclar-ve-yorumlar"></a>

# %% [markdown]
# ## 12. 🎓 Kişisel Deneyim ve Öğrenilenler
# <a id="kisisel-deneyim"></a>
